# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('C:/Users/RAM/Downloads/Problem 2-Para/Problem 2-Para/1964-09-25-01-00001.jpg',0)

# %%
plt.imshow(img,'gray')

# %%
img
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
img.shape
# Out:
# (2500, 1621)

# %%
cv2.imshow('image',img)
cv2.waitKey(10000)
cv2.destroyAllWindows()
