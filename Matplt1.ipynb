# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,5,6,9,7,4,8,6,9,8,7,2,1,0,7]

# %%
y=[4,8,3,9,7,6,1,2,5,6,9,7,5,6,3,4]

# %%
plt.plot(x,y, linewidth=5,color='r')

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.title('first graph')
plt.xlabel('x values')
plt.ylabel('y values')
plt.bar(x,y)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.title('first graph')
plt.xlabel('x values')
plt.ylabel('y values')
plt.plot(x,y)
