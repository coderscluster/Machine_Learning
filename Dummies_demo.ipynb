# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\CC\\National_share.csv')

# %%
df.head()
# Out:
#      Region  Area (km2)  National Share (%)
# 0  Northern      342239               10.55
# 1   Central      308350                9.37
# 2   Western      307713                9.36
# 3  Northern      240928                7.33
# 4   Western      196024                5.96

# %%
dummies=pd.get_dummies(df.Region)

# %%
merged_df=pd.concat([df,dummies],axis=1)

# %%
merged_df.head()
# Out:
#      Region  Area (km2)  National Share (%)  Central  Eastern  Northeastern  \
# 0  Northern      342239               10.55        0        0             0
# 1   Central      308350                9.37        1        0             0
# 2   Western      307713                9.36        0        0             0
# 3  Northern      240928                7.33        0        0             0
# 4   Western      196024                5.96        0        0             0
#
#    Northern  Southern  Western
# 0         1         0        0
# 1         0         0        0
# 2         0         0        1
# 3         1         0        0
# 4         0         0        1

# %%
new_df=merged_df.drop(['Region','Western'],axis=1)

# %%
new_df.head()
# Out:
#    Area (km2)  National Share (%)  Central  Eastern  Northeastern  Northern  \
# 0      342239               10.55        0        0             0         1
# 1      308350                9.37        1        0             0         0
# 2      307713                9.36        0        0             0         0
# 3      240928                7.33        0        0             0         1
# 4      196024                5.96        0        0             0         0
#
#    Southern
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
